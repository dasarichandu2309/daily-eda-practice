# %%
from scipy.stats import chi2

# %%
df = 2
alpha = 0.05

chi2_critical = chi2.ppf(1-alpha,df)
chi2_critical
# Out:
# np.float64(5.991464547107979)

# %% [markdown]
# ## P Value

# %%
import numpy as np
from scipy import stats

sample_data = [52,55,60,58,57,59,53]
pop_mu = 50

#t Testt
t_stat,p_value = stats.ttest_1samp(data,pop_mu)
print(t_stat)
print(p_value)
# Out:
# 5.796550698475776
# 0.0006658828290890589

# %%
from scipy.stats import norm
p_less_than_3 = norm.cdf(3,5,1)
p_less_than_4 = norm.cdf(4,5,1)
p_less_than_5 = norm.cdf(5,5,1)
p_less_than_6 = norm.cdf(6,5,1)
p_less_than_7 = norm.cdf(7,5,1)
p_less_than_8 = norm.cdf(8,5,1)
p_less_than_9 = norm.cdf(9,5,1)
print(p_less_than_3)
print(p_less_than_4) # 15.87% of customers waits less than 4 minutes
print(p_less_than_5)
print(p_less_than_6) # 84.13% of customers waits less than 6 minutes
print(p_less_than_7)
print(p_less_than_8)
print(p_less_than_9)
# Out:
# 0.022750131948179195
# 0.15865525393145707
# 0.5
# 0.8413447460685429
# 0.9772498680518208
# 0.9986501019683699
# 0.9999683287581669
